# %%
from project3_mlops_end_to_end.src.training.train import train_dummy_model
from project3_mlops_end_to_end.src.inference.predict import predict_dummy

model = train_dummy_model()
print('Trained model:', model)
print(predict_dummy(model, 'Hello world'))
